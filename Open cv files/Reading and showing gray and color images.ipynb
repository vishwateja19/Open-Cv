# %%
import numpy as np
import cv2  ## open cv framework

# %% [raw]
# ## Reading image from system and showing image cv2 with grayscale

# %%
## reading 
gray_scale=cv2.imread('./images/lena_gray_256.tif',0)

print(gray_scale.shape)
# Out:
# (256, 256)

# %%
print(gray_scale)
# Out:
# [[162 162 162 ... 168 171 155]
#  [162 162 162 ... 168 171 155]
#  [162 162 162 ... 168 171 155]
#  ...
#  [ 48  57  54 ...  75  97  88]
#  [ 46  50  52 ...  89 100  98]
#  [ 44  55  54 ...  97 100 105]]

# %%
## for showing the image 
cv2.imshow('teja',gray_scale)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
gray_scale=cv2.imread('./images/lena_gray_256.tif',0)
cv2.imshow('teja',gray_scale)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [raw]
# ## reading colour image

# %%
color_image=cv2.imread('./images/lena_color_256.tif',1)
cv2.imshow('teja',color_image)
cv2.waitKey()
cv2.destroyAllWindows()

# %% [raw]
# Now lets do some stuff with grayscale images:

# %%
gray_scale=cv2.imread('./images/mandril_gray.tif',0)
cv2.imshow('teja',gray_scale)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
value=gray_scale[80:120,70:100]

# %%
value
# Out:
# array([[146, 130, 119, ...,  82,  77,  80],
#        [149, 156, 166, ..., 120, 130, 126],
#        [159, 170, 181, ..., 155, 175, 169],
#        ...,
#        [210, 201, 184, ...,  89, 119, 138],
#        [172, 179, 177, ...,  60,  95, 133],
#        [102, 121, 140, ...,  75,  97, 137]], dtype=uint8)

# %%
cv2.imshow('ape',value)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
gray_scale[80:120,70:100]=0
cv2.imshow('ape',value)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
gray_scale[80:120,70:100]=255
cv2.imshow('ape',value)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
## Matplotlib with gray scale images

# %%
import matplotlib.pyplot as plt

# %%
## loading image using matplotlib

grey_image_mat=plt.imread('./images/lena_gray_512.tif')
plt.imshow(grey_image_mat)

# %%
## as it is showing as heatmap 

grey_image_mat=plt.imread('./images/lena_gray_256.tif')
plt.imshow(grey_image_mat,cmap='gray')

# %%
## Matplotlib with color images:

# %%
color_image_mat=plt.imread('./images/lena_color_512.tif')
plt.imshow(color_image_mat)

# %%
## loading image with matplotlib and showing it in matplotlib

# %%
color_image_mat=plt.imread('./images/lena_color_512.tif')
print(color_image_mat.shape)
plt.imshow(color_image_mat)
# Out:
# (512, 512, 3)

# %%
cv2.imshow('mat to opencv',color_image_mat[:,:,::-1])
cv2.waitKey()
cv2.destroyAllWindows()

# %%
## read in opencv and show in mat

# %%
color_image=cv2.imread('./images/mandril_color.tif',1)
plt.imshow(color_image[:,:,::-1])

# %% [raw]
# checking each channel in color images[RGB]

# %%
image=plt.imread('./images/lena_color_512.tif')
plt.subplot(2,2,1)
plt.title('original_image')
plt.xticks([])
plt.imshow(image)

plt.subplot(2,2,2)
plt.title('R channel')
plt.xticks([])
plt.imshow(image[:,:,0],cmap='gray')

plt.subplot(2,2,3)
plt.title('G channel')
plt.xticks([])
plt.imshow(image[:,:,1],cmap='gray')

plt.subplot(2,2,4)
plt.title('B channel')
plt.xticks([])
plt.imshow(image[:,:,2],cmap='gray')

# %% [raw]
#  Checking channels with open cv

# %%
image=cv2.imread('./images/mandril_color.tif',1)


plt.subplot(2,2,1)
plt.title('original image')
plt.xticks([])
plt.imshow(image[:,:,::-1])

plt.subplot(2,2,2)
plt.title('B channel')
plt.xticks([])
plt.imshow(image[:,:,0],cmap='gray')

plt.subplot(2,2,3)
plt.title('G channel')
plt.xticks([])
plt.imshow(image[:,:,1],cmap='gray')

plt.subplot(2,2,4)
plt.title('R channel')
plt.xticks([])
plt.imshow(image[:,:,2],cmap='gray')
